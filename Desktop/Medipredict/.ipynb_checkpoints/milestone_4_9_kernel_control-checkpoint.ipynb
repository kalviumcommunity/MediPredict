# %% [markdown]
# # Milestone 4.9 - Jupyter Kernel Control

# %% [markdown]
# This notebook demonstrates:
#
# - Running cells in order
# - Kernel memory behavior
# - Interrupting execution
# - Restarting kernel and resetting state

# %%
c = 10
print("Value of c:", c)

# %%
b =  c+5
print("Value of b:", b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 b =  c+5
#       2 print("Value of b:", b)
#
# NameError: name 'c' is not defined

# %% [markdown]
# This error occurs because the kernel executes cells in order.
# Variables must be defined before use.

# %%
while True:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 while True:
#       2     pass
#
# KeyboardInterrupt:

# %% [markdown]
# The kernel was interrupted to stop an infinite loop.
# Interrupt is useful when a cell runs too long or gets stuck.

# %% [markdown]
# Now restarting the kernel to clear all variables.

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %% [markdown]
# After restarting the kernel, all variables are cleared.
# We must rerun all cells to restore state.
