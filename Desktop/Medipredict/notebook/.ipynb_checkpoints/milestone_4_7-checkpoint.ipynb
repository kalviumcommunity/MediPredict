# %% [markdown]
# # Milestone 4.8 - Code vs Markdown Cellsprint("notebook working")

# %% [markdown]
# This notebook demonstrates the difference between Code cells and Markdown cells.
#
# - Code cells execute Python code
# - Markdown cells explain the code

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# This code adds two numbers and prints the result.

# %%
name = "Harshita"
print("Hello", name)
# Out:
# Hello Harshita

# %% [markdown]
# This code stores a name and prints a greeting message.
