# %% [markdown]
# # Markdown Demonstration Notebook
#
# This notebook demonstrates how to use Markdown for headings, lists, and code formatting in Jupyter.

# %% [markdown]
# ## Headings Example
#
# ### This is a subheading
#
# #### This is a smaller heading

# %% [markdown]
# ## Lists Example
#
# ### Unordered List
# - Item 1
# - Item 2
# - Item 3
#
# ### Ordered List
# 1. Step one
# 2. Step two
# 3. Step three

# %% [markdown]
# ## Code Formatting
#
# Inline code example: `print("Hello World")`
#
# Code block example:
#
# ```python
# def greet():
#     print("Hello from Markdown")

# %%
print("This is a code cell")
# Out:
# This is a code cell

# %% [markdown]
# ## Explanation
#
# The above code cell prints a simple message. Markdown helps explain what the code is doing.
